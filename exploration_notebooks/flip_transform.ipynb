# %%
import sys
sys.path.insert(0, '../')
import matplotlib.pyplot as plt
import numpy as np
from dataio.transformation.imageTransformations import RandomFlipTransform
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-2e7e93a747b5> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
# ----> 5 from dataio.transformation.imageTransformations import RandomFlipTransform
#
# ~/stroke_research/pCT_UNET/PerfusionCT-Net/dataio/transformation/__init__.py in <module>
# ----> 1 from dataio.transformation.transforms import Transformations
#       2
#       3
#       4 def get_dataset_transformation(name, opts=None, max_output_channels=None):
#       5     '''
#
# ~/stroke_research/pCT_UNET/PerfusionCT-Net/dataio/transformation/transforms.py in <module>
#       2 import torchsample.transforms as ts
#       3 # import torchvision.transforms as tv
# ----> 4 from torchio.transforms import Interpolation
#       5 from .imageTransformations import RandomElasticTransform, RandomAffineTransform, RandomNoiseTransform, RandomFlipTransform
#       6 from pprint import pprint
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchio-0.16.4-py3.7.egg/torchio/__init__.py in <module>
#       7 from . import utils
#       8 from .torchio import *
# ----> 9 from .transforms import *
#      10 from .data import io, sampler, inference, ImagesDataset, Image, Queue, Subject
#      11 # from . import datasets
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchio-0.16.4-py3.7.egg/torchio/transforms/__init__.py in <module>
#       6
#       7 # Augmentation
# ----> 8 from .augmentation.composition import OneOf
#       9 from .augmentation.composition import Compose
#      10
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchio-0.16.4-py3.7.egg/torchio/transforms/augmentation/composition.py in <module>
#       3 import torch
#       4 import numpy as np
# ----> 5 from torchvision.transforms import Compose as PyTorchCompose
#       6
#       7 from ...data.subject import Subject
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/__init__.py in <module>
#       1 import warnings
#       2
# ----> 3 from torchvision import models
#       4 from torchvision import datasets
#       5 from torchvision import ops
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/models/__init__.py in <module>
#      10 from .shufflenetv2 import *
#      11 from . import segmentation
# ---> 12 from . import detection
#      13 from . import video
#      14 from . import quantization
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/models/detection/__init__.py in <module>
# ----> 1 from .faster_rcnn import *
#       2 from .mask_rcnn import *
#       3 from .keypoint_rcnn import *
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/models/detection/faster_rcnn.py in <module>
#       5 import torch.nn.functional as F
#       6
# ----> 7 from torchvision.ops import misc as misc_nn_ops
#       8 from torchvision.ops import MultiScaleRoIAlign
#       9
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/ops/__init__.py in <module>
#      11 from ._register_onnx_ops import _register_custom_op
#      12
# ---> 13 _register_custom_op()
#      14
#      15
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torchvision-0.6.0-py3.7-macosx-10.9-x86_64.egg/torchvision/ops/_register_onnx_ops.py in _register_custom_op()
#      49     register_custom_op_symbolic('torchvision::roi_align', roi_align, _onnx_opset_version)
#      50     register_custom_op_symbolic('torchvision::roi_pool', roi_pool, _onnx_opset_version)
# ---> 51     register_custom_op_symbolic('torchvision::_new_empty_tensor_op', new_empty_tensor_op, _onnx_opset_version)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/onnx/__init__.py in register_custom_op_symbolic(symbolic_name, symbolic_fn, opset_version)
#     193 def register_custom_op_symbolic(symbolic_name, symbolic_fn, opset_version):
#     194     from torch.onnx import utils
# --> 195     return utils.register_custom_op_symbolic(symbolic_name, symbolic_fn, opset_version)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/onnx/utils.py in register_custom_op_symbolic(symbolic_name, symbolic_fn, opset_version)
#     738                            and sould start with a letter and contain only \
#     739                            alphanumerical characters"
# --> 740                            .format(symbolic_name))
#     741     ns, op_name = symbolic_name.split('::')
#     742     unaccepted_domain_names = ["onnx", "aten", "prim"]
#
# RuntimeError: Failed to register operator torchvision::_new_empty_tensor_op.                            The symbolic name must match the format Domain::Name,                            and sould start with a letter and contain only                            alphanumerical characters

# %%
dataset_path = '/Users/julian/stroke_research/data/all2016_subset_prepro/data_set.npz'
channel = 0
subj = 1
raw_images = np.load(dataset_path, allow_pickle=True)['ct_inputs'][subj][..., channel].astype(np.int16)
# raw_labels = np.load(dataset_path, allow_pickle=True)['ct_lesion_GT'][subj].astype(np.uint8)
raw_labels = np.load(dataset_path, allow_pickle=True)['lesion_GT'][subj].astype(np.uint8)
raw_images.shape
# Out:
# (79, 95, 79)

# %%
def show_slices(slices, cmap):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap=cmap, origin="lower")

def display(img_data, block=True, title=None, cmap='gray'):
    if len(img_data.shape) > 3 : img_data = np.squeeze(img_data)
    n_i, n_j, n_k = img_data.shape
    center_i = (n_i - 1) // 2
    center_j = (n_j - 1) // 2
    center_k = (n_k - 1) // 2
    print('Image center: ', center_i, center_j, center_k)
    center_vox_value = img_data[center_i, center_j, center_k]
    print('Image center value: ', center_vox_value)

    slice_0 = img_data[center_i, :, :]
    slice_1 = img_data[:, center_j, :]
    slice_2 = img_data[:, :, center_k]

    show_slices([slice_0, slice_1, slice_2], cmap=cmap)

    plt.suptitle("Center slices for image")
    if title:
        plt.suptitle(title)
    plt.show(block = block)
    return plt

# %%
display(raw_images)
display(raw_labels)
# Out:
# Image center:  39 47 39
# Image center value:  10
# Image center:  39 47 39
# Image center value:  0
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
flip_axis = (0)
random_flip_prob = 1
seed = 42
max_output_channels = 2

# %%
transform = RandomFlipTransform(axes=flip_axis, p=random_flip_prob, seed=seed, max_output_channels=max_output_channels),
transformed_input, transformed_label = transform(raw_images, raw_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-669ee84bd054> in <module>
# ----> 1 transform = RandomFlipTransform(axes=flip_axis, p=random_flip_prob, seed=seed, max_output_channels=max_output_channels),
#       2 transformed = transform(raw_images, raw_labels)
#       3
#       4
#
# NameError: name 'RandomFlipTransform' is not defined

# %%
display(transformed_input)
display(transformed_label)
